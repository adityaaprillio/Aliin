# %%
import numpy as np
a = np.array([[2,4,6],[4,3,5],[6,9,5]])
b = np.array([[5,6,3],[8,9,1]])
hasil = np.dot(a,b)
print(hasil)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-9374ce3b5d63> in <cell line: 4>()
#       2 a = np.array([[2,4,6],[4,3,5],[6,9,5]])
#       3 b = np.array([[5,6,3],[8,9,1]])
# ----> 4 hasil = np.dot(a,b)
#       5 print(hasil)
#
# ValueError: shapes (3,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)
